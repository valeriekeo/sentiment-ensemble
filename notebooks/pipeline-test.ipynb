# %%
import sys
import os
sys.path.append('/home/valkeo/sentiment-ensemble')
from src.pipeline import load_models, analyze_tweet

models = load_models(device='cuda')
# Out:
# 2026-05-19 17:53:46.717785: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-05-19 17:53:46.717851: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-19 17:53:46.719149: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-19 17:53:46.725839: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
result = analyze_tweet("This product is absolutely terrible, never buying again!", models)
print(result)
# Out:
# {'text': 'This product is absolutely terrible, never buying again!', 'sentiment': 'negative', 'triage_priority': 'RESPOND', 'entities': [], 'model_breakdown': {'roberta_label': 'negative', 'roberta_confidence': 0.946, 'vader_label': 'negative', 'vader_compound': -0.57}}

# %%
result = analyze_tweet("Love these! Slay!!", models)
print(result)
# Out:
# {'text': 'Love these! Slay!!', 'sentiment': 'positive', 'triage_priority': 'MONITOR', 'entities': [{'text': 'Slay', 'type': 'PERSON'}], 'model_breakdown': {'roberta_label': 'positive', 'roberta_confidence': 0.985, 'vader_label': 'positive', 'vader_compound': 0.725}}

# %%
result = analyze_tweet("I think I hate it but it kinda looks good.", models)
print(result)
# Out:
# {'text': 'I think I hate it but it kinda looks good.', 'sentiment': 'negative', 'triage_priority': 'VERIFY', 'entities': [], 'model_breakdown': {'roberta_label': 'negative', 'roberta_confidence': 0.697, 'vader_label': 'positive', 'vader_compound': 0.269}}
